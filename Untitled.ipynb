# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
import numpy as np
import pandas as pd
from sklearn.cluster import MeanShift
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import LinearRegression
from sklearn import model_selection
import math

# %%
ev_df = pd.read_csv(r"E:\Python-Notebooks\big_data_challenge\datasets_bdc\ElectricCarData_Clean.csv", index_col=False)

# %%
ev_df.dropna(inplace=True)
ev_df.reset_index(inplace=True)
ev_df.head(16)
# Out:
#     index        Brand                           Model  AccelSec  \
# 0       6  Volkswagen                          e-Golf        9.6
# 1      10    Mercedes                   EQC 400 4MATIC       5.1
# 2      14     Hyundai                   IONIQ Electric       9.7
# 3      23        Audi                       e-tron GT        3.5
# 4      24       Tesla   Model 3 Long Range Performance       3.4
# 5      28         BMW                        i3 120 Ah       7.3
# 6      40       Tesla               Model S Long Range       3.8
# 7      41     Hyundai             Kona Electric 39 kWh       9.9
# 8      42        Audi      e-tron Sportback 55 quattro       5.7
# 9      45         Kia                    e-Soul 64 kWh       7.9
# 10     47     Porsche                        Taycan 4S       4.0
# 11     53       Skoda                      Enyaq iV 80       8.8
# 12     54       Tesla               Model X Long Range       4.6
# 13     75         Kia                    e-Niro 39 kWh       9.8
# 14     83        Ford            Mustang Mach-E SR RWD       6.6
# 15     85        Fiat                   500e Hatchback       9.0
#
#     TopSpeed_KmH  Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge  \
# 0            150       190              168            220         Yes
# 1            180       370              216            440         Yes
# 2            165       250              153            210         Yes
# 3            240       425              197            850         Yes
# 4            261       435              167            910         Yes
# 5            150       235              161            270         Yes
# 6            250       515              184            560         Yes
# 7            155       255              154            210         Yes
# 8            200       380              228            610         Yes
# 9            167       365              175            340         Yes
# 10           250       365              195            730         Yes
# 11           160       420              183            560         Yes
# 12           250       450              211            490         Yes
# 13           155       235              167            230         Yes
# 14           180       360              194            380         Yes
# 15           150       250              168            330         Yes
#
#    PowerTrain    PlugType  BodyStyle Segment  Seats  PriceEuro   Sales
# 0         FWD  Type 2 CCS  Hatchback       C      5      31900    18277
# 1         AWD  Type 2 CCS        SUV       D      5      69484  132,214
# 2         FWD  Type 2 CCS   Liftback       C      5      34459     9796
# 3         AWD  Type 2 CCS      Sedan       F      4     125000     5369
# 4         AWD  Type 2 CCS      Sedan       D      5      61480   300471
# 5         RWD  Type 2 CCS  Hatchback       B      4      38017     4854
# 6         AWD      Type 2   Liftback       F      5      79990   157992
# 7         FWD  Type 2 CCS        SUV       B      5      33971     1461
# 8         AWD  Type 2 CCS        SUV       E      5      81639    10240
# 9         FWD  Type 2 CCS        SUV       B      5      36837      648
# 10        AWD  Type 2 CCS      Sedan       F      4     102945      130
# 11        RWD  Type 2 CCS        SUV       C      5      40000   326644
# 12        AWD      Type 2        SUV       F      7      85990    85077
# 13        FWD  Type 2 CCS        SUV       C      5      34400     1166
# 14        RWD  Type 2 CCS        SUV       D      5      46900    27211
# 15        FWD  Type 2 CCS  Hatchback       B      4      34900     3336

# %%
def get_unique_val_map(df, col):
    map = {}
    track = 1
    for i in range(len(df)):
        element = df.loc[i, col]
        if element not in map:
            map[element] = track
            track += 1
    return map

# %%
brand_dict = get_unique_val_map(ev_df, 'Brand')
print(brand_dict)
# Out:
# {'Volkswagen ': 1, 'Mercedes ': 2, 'Hyundai ': 3, 'Audi ': 4, 'Tesla ': 5, 'BMW ': 6, 'Kia ': 7, 'Porsche ': 8, 'Skoda ': 9, 'Ford ': 10, 'Fiat ': 11}

# %%
power_train_dict = get_unique_val_map(ev_df, 'PowerTrain')
print(power_train_dict)
# Out:
# {'FWD': 1, 'AWD': 2, 'RWD': 3}

# %%
plug_type_dict = get_unique_val_map(ev_df, 'PlugType')
print(plug_type_dict)
# Out:
# {'Type 2 CCS': 1, 'Type 2': 2}

# %%
body_style_dict = get_unique_val_map(ev_df, 'BodyStyle')
print(body_style_dict)
# Out:
# {'Hatchback': 1, 'SUV': 2, 'Liftback': 3, 'Sedan': 4}

# %%
segment_dict = get_unique_val_map(ev_df, 'Segment')
print(segment_dict)
# Out:
# {'C': 1, 'D': 2, 'F': 3, 'B': 4, 'E': 5}

# %%
replace_list = [brand_dict, power_train_dict, plug_type_dict, body_style_dict, segment_dict]

# %%
for dict in replace_list:
    for key in dict:
        val = dict[key]
        ev_df.replace(key, val, inplace=True)

# %%
ev_df.head(16)
# Out:
#     index  Brand                           Model  AccelSec  TopSpeed_KmH  \
# 0       6      1                         e-Golf        9.6           150
# 1      10      2                  EQC 400 4MATIC       5.1           180
# 2      14      3                  IONIQ Electric       9.7           165
# 3      23      4                      e-tron GT        3.5           240
# 4      24      5  Model 3 Long Range Performance       3.4           261
# 5      28      6                       i3 120 Ah       7.3           150
# 6      40      5              Model S Long Range       3.8           250
# 7      41      3            Kona Electric 39 kWh       9.9           155
# 8      42      4     e-tron Sportback 55 quattro       5.7           200
# 9      45      7                   e-Soul 64 kWh       7.9           167
# 10     47      8                       Taycan 4S       4.0           250
# 11     53      9                     Enyaq iV 80       8.8           160
# 12     54      5              Model X Long Range       4.6           250
# 13     75      7                   e-Niro 39 kWh       9.8           155
# 14     83     10           Mustang Mach-E SR RWD       6.6           180
# 15     85     11                  500e Hatchback       9.0           150
#
#     Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge  PowerTrain  \
# 0        190              168            220         Yes           1
# 1        370              216            440         Yes           2
# 2        250              153            210         Yes           1
# 3        425              197            850         Yes           2
# 4        435              167            910         Yes           2
# 5        235              161            270         Yes           3
# 6        515              184            560         Yes           2
# 7        255              154            210         Yes           1
# 8        380              228            610         Yes           2
# 9        365              175            340         Yes           1
# 10       365              195            730         Yes           2
# 11       420              183            560         Yes           3
# 12       450              211            490         Yes           2
# 13       235              167            230         Yes           1
# 14       360              194            380         Yes           3
# 15       250              168            330         Yes           1
#
#     PlugType  BodyStyle  Segment  Seats  PriceEuro   Sales
# 0          1          1        1      5      31900    18277
# 1          1          2        2      5      69484  132,214
# 2          1          3        1      5      34459     9796
# 3          1          4        3      4     125000     5369
# 4          1          4        2      5      61480   300471
# 5          1          1        4      4      38017     4854
# 6          2          3        3      5      79990   157992
# 7          1          2        4      5      33971     1461
# 8          1          2        5      5      81639    10240
# 9          1          2        4      5      36837      648
# 10         1          4        3      4     102945      130
# 11         1          2        1      5      40000   326644
# 12         2          2        3      7      85990    85077
# 13         1          2        1      5      34400     1166
# 14         1          2        2      5      46900    27211
# 15         1          1        4      4      34900     3336
