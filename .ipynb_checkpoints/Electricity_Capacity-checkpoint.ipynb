# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
import numpy as np
import pandas as pd
from sklearn.cluster import MeanShift
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import LinearRegression
from sklearn import model_selection
import math

# %%
ec_df = pd.read_csv(r"E:\Python-Notebooks\big_data_challenge\datasets_bdc\ELECCAP_20211206-014207.csv")
capacity = 'Installed electricity capacity by country/area (MW)'

# %%
ec_df.replace("..", np.nan, inplace=True)

# %%
ec_df.dropna(inplace=True)
#ec_df.reset_index(inplace=True)
ec_df.head(25)
# Out:
#     index Country/area                  Technology Grid connection  Year  \
# 0      21       Canada  On-grid Solar photovoltaic         On-grid  2000
# 1      22       Canada  On-grid Solar photovoltaic         On-grid  2001
# 2      23       Canada  On-grid Solar photovoltaic         On-grid  2002
# 3      24       Canada  On-grid Solar photovoltaic         On-grid  2003
# 4      25       Canada  On-grid Solar photovoltaic         On-grid  2004
# 5      26       Canada  On-grid Solar photovoltaic         On-grid  2005
# 6      27       Canada  On-grid Solar photovoltaic         On-grid  2006
# 7      28       Canada  On-grid Solar photovoltaic         On-grid  2007
# 8      29       Canada  On-grid Solar photovoltaic         On-grid  2008
# 9      30       Canada  On-grid Solar photovoltaic         On-grid  2009
# 10     31       Canada  On-grid Solar photovoltaic         On-grid  2010
# 11     32       Canada  On-grid Solar photovoltaic         On-grid  2011
# 12     33       Canada  On-grid Solar photovoltaic         On-grid  2012
# 13     34       Canada  On-grid Solar photovoltaic         On-grid  2013
# 14     35       Canada  On-grid Solar photovoltaic         On-grid  2014
# 15     36       Canada  On-grid Solar photovoltaic         On-grid  2015
# 16     37       Canada  On-grid Solar photovoltaic         On-grid  2016
# 17     38       Canada  On-grid Solar photovoltaic         On-grid  2017
# 18     39       Canada  On-grid Solar photovoltaic         On-grid  2018
# 19     40       Canada  On-grid Solar photovoltaic         On-grid  2019
# 20     41       Canada  On-grid Solar photovoltaic         On-grid  2020
# 21    147       Canada         Onshore wind energy         On-grid  2000
# 22    148       Canada         Onshore wind energy         On-grid  2001
# 23    149       Canada         Onshore wind energy         On-grid  2002
# 24    150       Canada         Onshore wind energy         On-grid  2003
#
#    Installed electricity capacity by country/area (MW)
# 0                                                   7
# 1                                                   9
# 2                                                  10
# 3                                                  12
# 4                                                  14
# 5                                                  18
# 6                                                  22
# 7                                                  29
# 8                                                  38
# 9                                                 107
# 10                                                249
# 11                                                628
# 12                                                766
# 13                                               1210
# 14                                               1843
# 15                                               2519
# 16                                               2665
# 17                                               2932
# 18                                               3095
# 19                                               3327
# 20                                               3342
# 21                                                 92
# 22                                                131
# 23                                                161
# 24                                                327

# %%
def getUniqueValues(list):
    vals = set()
    for l in list:
        vals.add(l)
    return vals

# %%
tech_col = getUniqueValues(ec_df['Technology'].tolist())
print(tech_col)
# Out:
# {'Pumped storage', 'Solid biofuels', 'Fossil fuels n.e.s.', 'Liquid biofuels', 'Renewable hydropower', 'Oil', 'Biogas', 'Renewable municipal waste', 'Natural gas', 'Coal and peat', 'Nuclear', 'Other non-renewable energy', 'Fossil fuels', 'Marine energy', 'Onshore wind energy', 'On-grid Solar photovoltaic'}

# %%
grid_conn_col = getUniqueValues(ec_df['Grid connection'].tolist())
print(grid_conn_col)
# Out:
# {'On-grid'}

# %%
capacity_dict = {}

for t in tech_col:
    year_dict = {}
    for i in range(len(ec_df)):
        tech = ec_df.loc[i, 'Technology']
        year = int(ec_df.loc[i, 'Year'])
coal and peat': {2005: 14703.0, 2006: 14701.0, 2007: 16179.0, 2008: 15940.0, 2009: 16000.0, 2010: 14123.0, 2011: 13849.0, 2012: 9900.0, 2013: 9884.0, 2014: 9827.0, 2015: 9791.0, 2016: 9641.0, 2017: 9636.0, 2018: 9689.0, 2019: 9689.0, 2020: 9309.0}, 'Nuclear': {2000: 10615.0, 2001: 10615.0, 2002: 10615.0, 2003: 10615.0, 2004: 12805.0, 2005: 13345.0, 2006: 13345.0, 2007: 13345.0, 2008: 13345.0, 2009: 12665.0, 2010: 12665.0, 2011: 12665.0, 2012: 13370.0, 2013: 14033.0, 2014: 14033.0, 2015: 14033.0, 2016: 14033.0, 2017: 14033.0, 2018: 14033.0, 2019: 14033.0, 2020: 14033.0}, 'Other non-renewable energy': {2000: 7.0, 2001: 9.0, 2002: 7.0, 2003: 5.5, 2004: 5.5, 2005: 17.5, 2006: 17.5, 2007: 17.5, 2008: 17.5, 2009: 18.0, 2010: 17.5, 2011: 17.5, 2012: 38.5, 2013: 38.5, 2014: 38.5, 2015: 38.5, 2016: 38.5, 2017: 37.5, 2018: 37.5, 2019: 37.5, 2020: 37.5}, 'Fossil fuels': {2000: 31838.0, 2001: 33029.0, 2002: 33197.0, 2003: 34856.0, 2004: 34309.0, 2005: 35513.0, 2006: 35416.0, 2007: 35504.0, 2008: 35320.0, 2009: 39137.0, 2010: 38568.0, 2011: 37060.0, 2012: 35321.0, 2013: 33125.0, 2014: 32912.0, 2015: 34360.0, 2016: 34979.0, 2017: 34628.0, 2018: 34631.0, 2019: 34875.0, 2020: 34903.9}, 'Marine energy': {2000: 20.0, 2001: 20.0, 2002: 20.0, 2003: 20.0, 2004: 20.0, 2005: 20.0, 2006: 20.0, 2007: 20.0, 2008: 20.0, 2009: 20.0, 2010: 20.0, 2011: 20.0, 2012: 20.0, 2013: 20.0, 2014: 20.0, 2015: 20.0, 2016: 20.0, 2017: 20.0, 2018: 20.0, 2019: 20.0, 2020: 20.0}, 'Onshore wind energy': {2000: 92.0, 2001: 131.0, 2002: 161.0, 2003: 327.0, 2004: 444.0, 2005: 677.0, 2006: 1423.0, 2007: 1 ...

# %%
for tc in tech_col:
    for y in range(2000, 2021):
        if y in capacity_dict[tc]:
            #print(capacity_dict[tc][y])
            plt.plot(y, capacity_dict[tc][y], 'ro')
            
    plt.xlabel('year')
    plt.ylabel('capacity for '+tc)
    plt.show()

# %%
rgbs = ['#880401', '#eb0905', '#eb7500', '#f2ff00',
        '#aaff00', '#33ff00', '#13d893', '#35eaf3',
        '#35b4f3', '#3558f3', '#9092f9', '#8028cc',
       '#b928cc', '#db48c0', '#040104', '#6a6869']

index = 0

for tc in tech_col:
    x = []
    y = []
    for year in range(2000, 2021):
        if year in capacity_dict[tc]:
            x.append(year)
            y.append(capacity_dict[tc][year])
    lr = LinearRegression()
    x = np.array(x)
    y = np.array(y)
    #print(type(x))
    x_train, x_test, y_train, y_test = model_selection.train_test_split(x,y, test_size=0.2)
    lr.fit(x_train.reshape(-1,1), y_train.reshape(-1,1))
    #score = lr.score(x_test.reshape(-1,1), y_test.reshape(-1,1))
    #print(score)
    
    years = []
    preds = []
    
    for year in range(2021, 2041):
        pred = lr.predict(np.array([year]).reshape(-1,1))[0][0]
        years.append(year)
        preds.append(pred)
        #print(pred[0][0])

    plt.plot(years, preds ,marker='o', markersize=1, label=tc, color=rgbs[index])
    
    index += 1

plt.legend(loc='best')
plt.show()

# %%
plt
